# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
Data = pd.read_csv('./cleaned_grade9_data.csv')

# %%
Data.head()
# Out:
#                    subject  Total exam entries  number achieving 9  \
# 0          Ancient History                1219                 148
# 1      Any classical study               14133                4054
# 2  Any design & technology              131386                5346
# 3      Any modern language              313404               31713
# 4              Any Science             1045343               72145
#
#    percent of 9s
# 0             12
# 1             29
# 2              4
# 3             10
# 4              7

# %%
Data.tail()
# Out:
#               subject  Total exam entries  number achieving 9  percent of 9s
# 33            Physics              170230               22410             13
# 34  Religious Studies              224466               17726              8
# 35     Social Studies               67430                2383              4
# 36            Spanish              120059                7486              6
# 37         Statistics               25637                1219              5

# %%
Data
# Out:
#                          subject  Total exam entries  number achieving 9  \
# 0                Ancient History                1219                 148
# 1            Any classical study               14133                4054
# 2        Any design & technology              131386                5346
# 3            Any modern language              313404               31713
# 4                    Any Science             1045343               72145
# 5                 Art and Design              183270               10342
# 6                Biblical Hebrew                 586                 104
# 7                        Biology              175353               22217
# 8                       Business              113577                4269
# 9                      Chemistry              170573               22533
# 10        Classical Civilisation                4305                 436
# 11               Classical Greek                 915                 509
# ...

# %%
# set up data
labels = ('Classical Greek','Latin','Other Modern Languages','Any classical study','Biblical Hebrew')
index = (1, 3, 5, 7, 9)
values = (56,36,34,29,18)
plt.bar(labels, values)
plt.xticks(labels, rotation = 90)
plt.xlabel("subjects")
plt.ylabel("percent of students achieving grade 9")
plt.title(" top 5 highest subject student are achieving a grade 9 ")
# Out:
# Text(0.5, 1.0, ' top 5 highest subject student are achieving a grade 9 ')

# %%
labels = ('Engineering','English Language','English Literature','Film Studies','Food Preparation & Nutrition')
index = (1, 3, 5, 7, 9)
values = (2,3,4,4,4)
plt.bar(labels, values)
plt.xticks(labels, rotation = 90)
plt.xlabel("subjects")
plt.ylabel("percent of students achieving grade 9")
plt.title(" top 5 lowest subject student are achieving a grade 9 ")
# Out:
# Text(0.5, 1.0, ' top 5 lowest subject student are achieving a grade 9 ')
